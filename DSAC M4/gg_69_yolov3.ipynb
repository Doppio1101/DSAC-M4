# %% [markdown]
# 먼저 아래 명령으로 tensorflow 1.15 버전을 선택하고 필요한 패키지를 설치한다. pydrive 는 YouTube 비디오를 다운받기 위한 라이브러리이다. (아래 코드는 Colab 에서 수행하기 위한 코드이다.)

# %%
import sys
print(sys.version)
# Out:
# 3.6.9 (default, Oct  8 2020, 12:12:24)
# [GCC 8.4.0]

# %%
# !git clone https://github.com/ultralytics/yolov3.git
# %cd yolov3
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 9667 (delta 8), reused 8 (delta 3), pack-reused 9642
# Receiving objects: 100% (9667/9667), 8.23 MiB | 14.02 MiB/s, done.
# Resolving deltas: 100% (6581/6581), done.
# /content/yolov3

# %%
# !chmod +x weights/download_yolov3_weights.sh
# Out:
# chmod: cannot access 'weights/download_yolov3_weights.sh': No such file or directory

# %%
# !weights/download_yolov3_weights.sh
# Out:
# /bin/bash: weights/download_yolov3_weights.sh: No such file or directory

# %%
# !python3 detect.py --weights yolov3-spp.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images', update=False, view_img=False, weights=['yolov3-spp.pt'])
# Using torch 1.7.0+cu101 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
#
# ...
# 100% 120M/120M [00:01<00:00, 104MB/s]
#
# Fusing layers...
# Model Summary: 269 layers, 62971933 parameters, 0 gradients
# image 1/2 /content/yolov3/data/images/bus.jpg: 640x480 4 persons, 1 buss, Done. (0.056s)
# image 2/2 /content/yolov3/data/images/zidane.jpg: 384x640 2 persons, 2 ties, Done. (0.028s)
# Results saved to runs/detect/exp
# Done. (0.323s)

# %%
# !python3 detect.py --cfg cfg/yolov3-spp.cfg --weights weights/yolov3-spp.weights
# Out:
# usage: detect.py [-h] [--weights WEIGHTS [WEIGHTS ...]] [--source SOURCE]
#                  [--img-size IMG_SIZE] [--conf-thres CONF_THRES]
#                  [--iou-thres IOU_THRES] [--device DEVICE] [--view-img]
#                  [--save-txt] [--save-conf] [--classes CLASSES [CLASSES ...]]
#                  [--agnostic-nms] [--augment] [--update] [--project PROJECT]
#                  [--name NAME] [--exist-ok]
# detect.py: error: unrecognized arguments: --cfg cfg/yolov3-spp.cfg

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

img = mpimg.imread('./runs/detect/exp/bus.jpg')
plt.imshow(img)
